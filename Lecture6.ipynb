# %% [markdown]
# <a href="https://colab.research.google.com/github/TanisqSinghal/Data_science_internship/blob/main/Lecture6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.reset_index(drop="first",inplace=True)
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df["year"].unique() #returns unique elements of a particular column in dataframe
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960])

# %%
for i in df.columns :
  print(df[i].unique());
# Out:
# [1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960]
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']
# [112 118 132 129 121 135 148 136 119 104 115 126 141 125 149 170 158 133
#  114 140 145 150 178 163 172 199 184 162 146 166 171 180 193 181 183 218
#  230 242 209 191 194 196 236 235 229 243 264 272 237 211 201 204 188 227
#  234 302 293 259 203 233 267 269 270 315 364 347 312 274 278 284 277 317
#  313 318 374 413 405 355 306 271 301 356 348 422 465 467 404 305 336 340
#  362 363 435 491 505 359 310 337 360 342 406 396 420 472 548 559 463 407
#  417 391 419 461 535 622 606 508 390 432]

# %%
for i in df.columns:
  if i == "year" or i == "passengers":
    print(df[i].unique())
# Out:
# [1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960]
# [112 118 132 129 121 135 148 136 119 104 115 126 141 125 149 170 158 133
#  114 140 145 150 178 163 172 199 184 162 146 166 171 180 193 181 183 218
#  230 242 209 191 194 196 236 235 229 243 264 272 237 211 201 204 188 227
#  234 302 293 259 203 233 267 269 270 315 364 347 312 274 278 284 277 317
#  313 318 374 413 405 355 306 271 301 356 348 422 465 467 404 305 336 340
#  362 363 435 491 505 359 310 337 360 342 406 396 420 472 548 559 463 407
#  417 391 419 461 535 622 606 508 390 432]

# %%
df["month"].value_counts() #returns the count value of a columns
# Out:
# month
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: count, dtype: int64

# %%
df["month"].value_counts().reset_index()
# Out:
#    month  count
# 0    Jan     12
# 1    Feb     12
# 2    Mar     12
# 3    Apr     12
# 4    May     12
# 5    Jun     12
# 6    Jul     12
# 7    Aug     12
# 8    Sep     12
# 9    Oct     12
# 10   Nov     12
# 11   Dec     12

# %%
df.dropna() #delete that particular row if found any NaN value in any column of a row
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.drop_duplicates() #delete the duplicate rows in which all col has same value
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.drop_duplicates(subset=["month"]) #subset means delete on the basis of any particular col
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118

# %%
df.drop_duplicates(subset=["month"],keep="last") #if keep will be last, it stores the last occurance of the value not the first
# Out:
#      year month  passengers
# 132  1960   Jan         417
# 133  1960   Feb         391
# 134  1960   Mar         419
# 135  1960   Apr         461
# 136  1960   May         472
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
df.drop(columns=["month","year"], index=[2,3],errors="ignore") #columns means it will delete the complete col
#index means it will delete that particular index, ignore means ignore the error if any data not found
# Out:
#      passengers
# 0           112
# 1           118
# 4           121
# 5           135
# 6           148
# ..          ...
# 139         606
# 140         508
# 141         461
# 142         390
# 143         432
#
# [142 rows x 1 columns]

# %%
df_1 = df.iloc[0:, 0:2]
df_1
# Out:
#      year month
# 0    1949   Jan
# 1    1949   Feb
# 2    1949   Mar
# 3    1949   Apr
# 4    1949   May
# ..    ...   ...
# 139  1960   Aug
# 140  1960   Sep
# 141  1960   Oct
# 142  1960   Nov
# 143  1960   Dec
#
# [144 rows x 2 columns]

# %%
df_2 = df.iloc[0:4, 0:2]
df_2
# Out:
#    year month
# 0  1949   Jan
# 1  1949   Feb
# 2  1949   Mar
# 3  1949   Apr

# %%
df.sort_index() #sort on the basis of index in the dataframe
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.sort_values(by="passengers") #sort on the basis of passengers in the dataframe
# Out:
#      year month  passengers
# 10   1949   Nov         104
# 0    1949   Jan         112
# 22   1950   Nov         114
# 12   1950   Jan         115
# 11   1949   Dec         118
# ..    ...   ...         ...
# 137  1960   Jun         535
# 126  1959   Jul         548
# 127  1959   Aug         559
# 139  1960   Aug         606
# 138  1960   Jul         622
#
# [144 rows x 3 columns]

# %%
df.sort_values(by="passengers").reset_index() #given the index to the sorted dataframe
# Out:
#      index  year month  passengers
# 0       10  1949   Nov         104
# 1        0  1949   Jan         112
# 2       22  1950   Nov         114
# 3       12  1950   Jan         115
# 4       11  1949   Dec         118
# ..     ...   ...   ...         ...
# 139    137  1960   Jun         535
# 140    126  1959   Jul         548
# 141    127  1959   Aug         559
# 142    139  1960   Aug         606
# 143    138  1960   Jul         622
#
# [144 rows x 4 columns]

# %%
df.sort_values(by="passengers",ascending=False) #sort in descending order
# Out:
#      year month  passengers
# 138  1960   Jul         622
# 139  1960   Aug         606
# 127  1959   Aug         559
# 126  1959   Jul         548
# 137  1960   Jun         535
# ..    ...   ...         ...
# 11   1949   Dec         118
# 12   1950   Jan         115
# 22   1950   Nov         114
# 0    1949   Jan         112
# 10   1949   Nov         104
#
# [144 rows x 3 columns]

# %%
import pandas as pd
My_dict = {
    "Name" : ["Gaurav", "Sourav", "Sachin", "Mohit"],
    "values" : [20,20,30,30],
}
my_df = pd.DataFrame(My_dict)
my_df
# Out:
#      Name  values
# 0  Gaurav      20
# 1  Sourav      20
# 2  Sachin      30
# 3   Mohit      30

# %%
my_df.sort_values(by=["Name", "values"],ascending=False) #first sort on the basis of name then values in descending order
# Out:
#      Name  values
# 1  Sourav      20
# 2  Sachin      30
# 3   Mohit      30
# 0  Gaurav      20

# %%
df.set_index("month") #use month as a index not by default 0,1,2,3....
# Out:
#        year  passengers
# month
# Jan    1949         112
# Feb    1949         118
# Mar    1949         132
# Apr    1949         129
# May    1949         121
# ...     ...         ...
# Aug    1960         606
# Sep    1960         508
# Oct    1960         461
# Nov    1960         390
# Dec    1960         432
#
# [144 rows x 2 columns]

# %%
df.set_index("year").loc[1949] #loc means location,give all values equal to 1949
# Out:
#      month  passengers
# year
# 1949   Jan         112
# 1949   Feb         118
# 1949   Mar         132
# 1949   Apr         129
# 1949   May         121
# 1949   Jun         135
# 1949   Jul         148
# 1949   Aug         148
# 1949   Sep         136
# 1949   Oct         119
# 1949   Nov         104
# 1949   Dec         118

# %%
import numpy as np
My_dict = {
    "Name" : ["Gaurav", "Sourav", "Sachin", "Mohit","rahul"],
    "values" : [20,20,30,30,np.nan],
}
my_df_2 = pd.DataFrame(My_dict)
my_df_2
# Out:
#      Name  values
# 0  Gaurav    20.0
# 1  Sourav    20.0
# 2  Sachin    30.0
# 3   Mohit    30.0
# 4   rahul     NaN

# %%
import warnings
my_df_2.fillna(my_df_2['values'].mean()).filter() #fill tha NaN value in values with mean of values
# Out:
#      Name  values
# 0  Gaurav    20.0
# 1  Sourav    20.0
# 2  Sachin    30.0
# 3   Mohit    30.0
# 4   rahul    25.0

# %%
import numpy as np
My_dict = {
    "Name" : ["Gaurav", np.nan, "Sachin", "Mohit","rahul"],
    "values" : [20,20,30,30,np.nan],
}
my_df_3 = pd.DataFrame(My_dict)
my_df_3
# Out:
#      Name  values
# 0  Gaurav    20.0
# 1     NaN    20.0
# 2  Sachin    30.0
# 3   Mohit    30.0
# 4   rahul     NaN

# %%
my_df_3["Name"].fillna(method="bfill") #fill tha NaN value with the forward or backward value of the dataframe
# Out:
# /tmp/ipython-input-45-3167234103.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   my_df_3["Name"].fillna(method="bfill") #fill tha NaN value with mean
# 0    Gaurav
# 1    Sachin
# 2    Sachin
# 3     Mohit
# 4     rahul
# Name: Name, dtype: object

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
def percentage(x) :
  return (x/622) * 100
percentage(134)
df["passengers_percent"] = percentage(df["passengers"]) #make a new col passengers oercentage and call percentage fucntion
df
# Out:
#      year month  passengers  passengers_percent
# 0    1949   Jan         112           18.006431
# 1    1949   Feb         118           18.971061
# 2    1949   Mar         132           21.221865
# 3    1949   Apr         129           20.739550
# 4    1949   May         121           19.453376
# ..    ...   ...         ...                 ...
# 139  1960   Aug         606           97.427653
# 140  1960   Sep         508           81.672026
# 141  1960   Oct         461           74.115756
# 142  1960   Nov         390           62.700965
# 143  1960   Dec         432           69.453376
#
# [144 rows x 4 columns]

# %%
df["p_Percentage"] = df["passengers"].apply(percentage) #apply any external function
df
# Out:
#      year month  passengers  passengers_percent  p_Percentage
# 0    1949   Jan         112           18.006431     18.006431
# 1    1949   Feb         118           18.971061     18.971061
# 2    1949   Mar         132           21.221865     21.221865
# 3    1949   Apr         129           20.739550     20.739550
# 4    1949   May         121           19.453376     19.453376
# ..    ...   ...         ...                 ...           ...
# 139  1960   Aug         606           97.427653     97.427653
# 140  1960   Sep         508           81.672026     81.672026
# 141  1960   Oct         461           74.115756     74.115756
# 142  1960   Nov         390           62.700965     62.700965
# 143  1960   Dec         432           69.453376     69.453376
#
# [144 rows x 5 columns]

# %%
df["month"].apply(len) #len of the string of month
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 139    3
# 140    3
# 141    3
# 142    3
# 143    3
# Name: month, Length: 144, dtype: int64

# %% [markdown]
# #Group by function in pandas

# %%
df.head(20)
# Out:
#     year month  passengers  passengers_percent  p_Percentage
# 0   1949   Jan         112           18.006431     18.006431
# 1   1949   Feb         118           18.971061     18.971061
# 2   1949   Mar         132           21.221865     21.221865
# 3   1949   Apr         129           20.739550     20.739550
# 4   1949   May         121           19.453376     19.453376
# 5   1949   Jun         135           21.704180     21.704180
# 6   1949   Jul         148           23.794212     23.794212
# 7   1949   Aug         148           23.794212     23.794212
# 8   1949   Sep         136           21.864952     21.864952
# 9   1949   Oct         119           19.131833     19.131833
# 10  1949   Nov         104           16.720257     16.720257
# 11  1949   Dec         118           18.971061     18.971061
# 12  1950   Jan         115           18.488746     18.488746
# 13  1950   Feb         126           20.257235     20.257235
# 14  1950   Mar         141           22.668810     22.668810
# 15  1950   Apr         135           21.704180     21.704180
# 16  1950   May         125           20.096463     20.096463
# 17  1950   Jun         149           23.954984     23.954984
# 18  1950   Jul         170           27.331190     27.331190
# 19  1950   Aug         170           27.331190     27.331190

# %%
df.groupby("month").passengerss.mean() #gives how many passengers came in respective months
# Out:
# /tmp/ipython-input-54-3273031453.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("month").passengers.mean()
# month
# Jan    241.750000
# Feb    235.000000
# Mar    270.166667
# Apr    267.083333
# May    271.833333
# Jun    311.666667
# Jul    351.333333
# Aug    351.083333
# Sep    302.416667
# Oct    266.583333
# Nov    232.833333
# Dec    261.833333
# Name: passengers, dtype: float64

# %%
df.groupby("month").passengers.agg({"mean","max","sum","min","count"}).sort_values(by="sum")
# Out:
# /tmp/ipython-input-60-2055177440.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("month").passengers.agg({"mean","max","sum","min","count"}).sort_values(by="sum")
#              mean  count  max   sum  min
# month
# Nov    232.833333     12  390  2794  104
# Feb    235.000000     12  391  2820  118
# Jan    241.750000     12  417  2901  112
# Dec    261.833333     12  432  3142  118
# Oct    266.583333     12  461  3199  119
# Apr    267.083333     12  461  3205  129
# Mar    270.166667     12  419  3242  132
# May    271.833333     12  472  3262  121
# Sep    302.416667     12  508  3629  136
# Jun    311.666667     12  535  3740  135
# Aug    351.083333     12  606  4213  148
# Jul    351.333333     12  622  4216  148
